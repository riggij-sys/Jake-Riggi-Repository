# %% [markdown]
# <a href="https://colab.research.google.com/github/riggij-sys/Jake-Riggi-Repository/blob/main/JakeRiggi_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import matplotlib

from matplotlib import pyplot as plt

import pandas as pd

import numpy as np

#this loads the necesary tools to allow us to visualize our data in charts and plots

# %% [markdown]
# ## Jake Riggi
# *Intro to Nueral Data Analysis*
#
# **2/8/25**

# %%
url = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
pandas_data1=pd.read_csv(url)
pandas_data1
#this cell imports our csv file labled v_rest_sst.csv into a table
# the panda_data1 at the bottom allows us to view this variable we created from
# reading our csv file
# Out:
#      -68.24292501
# 0      -69.601582
# 1      -76.034201
# 2      -71.161184
# 3      -76.354027
# 4      -70.891050
# ..            ...
# 494    -75.487872
# 495    -68.594480
# 496    -69.718097
# 497    -65.595358
# 498    -75.106787
#
# [499 rows x 1 columns]

# %%
url_2 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
pandas_data2=pd.read_csv(url_2)
pandas_data2

#this cell does the exact same thing as the cell above but for our 2nd csv file
# Out:
#      -70.21126938
# 0      -49.922277
# 1      -75.719394
# 2      -72.368070
# 3      -63.093008
# 4      -75.546930
# ..            ...
# 494    -70.519670
# 495    -69.917476
# 496    -71.446082
# 497    -49.804129
# 498    -54.084279
#
# [499 rows x 1 columns]

# %%
data1 = pandas_data1.values.tolist()
data2 = pandas_data2.values.tolist()
data1
#this cell turns our pd into a list
# Out:
# [[-69.60158234],
#  [-76.03420105],
#  [-71.16118393],
#  [-76.35402679],
#  [-70.89105013],
#  [-64.11880341],
#  [-72.8632112],
#  [-78.96890068],
#  [-55.4531032],
#  [-60.98506045],
#  [-66.61118807],
#  [-67.08294233],
#  [-73.90523593],
#  [-74.63317594],
#  [-49.27067811],
#  [-76.05053997],
#  [-65.45417595],
#  [-58.53314018],
#  [-66.28985665],
#  [-64.09106996],
#  [-71.49303228],
#  [-65.11718958],
#  [-73.74140637],
#  [-74.81462097],
#  [-71.32343356],
#  [-74.46990373],
#  [-65.03939126],
#  [-71.94757271],
#  [-73.42034054],
#  [-71.10602856],
#  [-61.28795481],
#  [-73.79654069],
#  [-64.48533249],
#  [-69.65824959],
#  [-73.71225967],
#  [-85.56860669],
#  [-57.49219704],
#  [-76.91730436],
#  [-62.61127641],
#  [-67.08071963],
#  [-78.45983535],
#  [-78.87342682],
#  [-76.14055703],
#  [-62.40101166],
#  [-72.41336346],
#  [-62.03701146],
#  [-63.30990855],
#  [-62.02654052],
#  [-73.0206111],
#  [-63.11713295],
#  [-70.05060087],
#  [-75.7537974],
# ...

# %%
data1 = np.squeeze(data1)
data2 = np.squeeze(data2)
#in the previous cell when we turned our PandasDataFrames into a list, it put all of our data into brackets.

# %%
len(data1)
#the len function lets us know the length of a list, in this case our "data1" list
# Out:
# 499

# %%
slice1_data2=data2[2:6]
print(slice1_data2)
# we were instructed to output the 3rd-6th item, which while can be done by
# indexing all of the values, can be more easily done through slicing at the 3rd
# value, which python calls 2, to the 7th value called 6
# Out:
# [-72.36807022 -63.09300825 -75.5469301  -66.51929994]

# %%
print(data1[-1])
print(data1[-2])
#in this cell I used negative indexing to output the last 2 numbers in the data1 list
# Out:
# -75.10678711
# -65.59535842

# %%
type(data2)
# the type function is returning as numpy,ndarray likely because we turned our
# list back into this type of variable when we used the "numpy.squeez()"
# function
# Out:
# numpy.ndarray

# %%
plt.hist(data1)
# Out:
# (array([  3.,   4.,  23.,  77., 125., 107.,  90.,  42.,  21.,   7.]),
#  array([-88.07835484, -84.19758717, -80.31681949, -76.43605182,
#         -72.55528415, -68.67451648, -64.7937488 , -60.91298113,
#         -57.03221346, -53.15144578, -49.27067811]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data1)
plt.xlabel('voltage')
plt.ylabel("counts")
# Out:
# Text(0, 0.5, 'counts')

# %%
plt.hist(data2)
plt.xlabel('voltage')
plt.ylabel("counts")
# Out:
# Text(0, 0.5, 'counts')

# %% [markdown]
# ##Differences
#
#
# 1.   our sst histogram has the highest counted voltage around 125 while our pvalb is more like 145
#
# 2.   while our highest counted value was -70mv for both hitograms, the pvalb cells seem to have a more negative resting membrane potential on average compared to the sst resting membrane potentials

# %%
data3=[data1,data2]
#this is the syntax to create lists of lists, and that is what we are required to do with our data3 variable

# %%
print(data3[-1][-1])
#indexing lists of lists require us to first put which list we are searching through, in this case -1 saying it is our last list. Our second index value says which value in our last list we want to index, in this case the last value. So, we are searching the last value on the last list.
# Out:
# -54.08427915
