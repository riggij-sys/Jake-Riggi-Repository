# %% [markdown]
# <a href="https://colab.research.google.com/github/riggij-sys/Jake-Riggi-Repository/blob/main/coding_homework_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Jake Riggi
#
# *NEUR 265*
#
# **2/15/25**

# %%
import numpy as np

import matplotlib.pyplot as plt

import statistics as st

# %%
url='https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'
url2= 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'

v_rest_pvalb=np.loadtxt(url)
v_rest_sst=np.loadtxt(url2)
#this cell imported the raw data files and turned them into variables that can be turned into numpy arrays

# %%
v_rest=np.array([v_rest_pvalb,v_rest_sst])
print(v_rest)
# this code cell concnetrates our 2 previous variable from before into a matrix,
# and both of the two variables from before were sliced in order to make the
# matrix 2, 13 as required
# Out:
# [[-70.21126938 -49.92227745 -75.71939359 -72.36807022 -63.09300825
#   -75.5469301  -66.51929994 -71.50055833 -69.19734478 -76.38503876
#   -65.96166784 -65.47980734 -59.95571342 -69.94688056 -74.56247482
#   -69.56489473 -66.74425422 -71.57112946 -71.23040619 -71.99371229
#   -79.66145376 -60.18065071 -70.27087275 -69.51328714 -76.44443893
#   -61.01587601 -66.54598575 -68.57077581 -72.52978809 -69.55428314
#   -79.4150077  -66.12706146 -69.61513367 -69.59012375 -78.5484375
#   -69.97646046 -63.67217359 -69.80182966 -72.46670193 -72.17225588
#   -63.49881536 -67.87744827 -75.48496437 -73.37054698 -73.57516549
#   -68.23623112 -64.82718235 -61.53974394 -64.49179316 -73.83959484
#   -65.12582397 -76.59335175 -71.79500173 -68.45139211 -70.45548483
#   -78.36537799 -73.34691535 -65.32437515 -79.56857345 -73.24215508
#   -69.29635385 -69.78741977 -75.46377702 -62.96309948 -71.2908991
#   -66.48377482 -70.91091711 -73.812372   -72.20985667 -69.96945784
# ...

# %%
print(v_rest.shape)
print(v_rest.size)
print(v_rest)
#this cell is looking at the size and shape, making sure it is 2 rows by 13 columns, and the size looks at the total nubmer of values
# Out:
# (2, 500)
# 1000
# [[-70.21126938 -49.92227745 -75.71939359 -72.36807022 -63.09300825
#   -75.5469301  -66.51929994 -71.50055833 -69.19734478 -76.38503876
#   -65.96166784 -65.47980734 -59.95571342 -69.94688056 -74.56247482
#   -69.56489473 -66.74425422 -71.57112946 -71.23040619 -71.99371229
#   -79.66145376 -60.18065071 -70.27087275 -69.51328714 -76.44443893
#   -61.01587601 -66.54598575 -68.57077581 -72.52978809 -69.55428314
#   -79.4150077  -66.12706146 -69.61513367 -69.59012375 -78.5484375
#   -69.97646046 -63.67217359 -69.80182966 -72.46670193 -72.17225588
#   -63.49881536 -67.87744827 -75.48496437 -73.37054698 -73.57516549
#   -68.23623112 -64.82718235 -61.53974394 -64.49179316 -73.83959484
#   -65.12582397 -76.59335175 -71.79500173 -68.45139211 -70.45548483
#   -78.36537799 -73.34691535 -65.32437515 -79.56857345 -73.24215508
#   -69.29635385 -69.78741977 -75.46377702 -62.96309948 -71.2908991
#   -66.48377482 -70.91091711 -73.812372   -72.20985667 -69.96945784
# ...

# %%
print(v_rest[0])
#this code indexed the first row of our numpy array
# Out:
# [-70.21126938 -49.92227745 -75.71939359 -72.36807022 -63.09300825
#  -75.5469301  -66.51929994 -71.50055833 -69.19734478 -76.38503876
#  -65.96166784 -65.47980734 -59.95571342 -69.94688056 -74.56247482
#  -69.56489473 -66.74425422 -71.57112946 -71.23040619 -71.99371229
#  -79.66145376 -60.18065071 -70.27087275 -69.51328714 -76.44443893
#  -61.01587601 -66.54598575 -68.57077581 -72.52978809 -69.55428314
#  -79.4150077  -66.12706146 -69.61513367 -69.59012375 -78.5484375
#  -69.97646046 -63.67217359 -69.80182966 -72.46670193 -72.17225588
#  -63.49881536 -67.87744827 -75.48496437 -73.37054698 -73.57516549
#  -68.23623112 -64.82718235 -61.53974394 -64.49179316 -73.83959484
#  -65.12582397 -76.59335175 -71.79500173 -68.45139211 -70.45548483
#  -78.36537799 -73.34691535 -65.32437515 -79.56857345 -73.24215508
#  -69.29635385 -69.78741977 -75.46377702 -62.96309948 -71.2908991
#  -66.48377482 -70.91091711 -73.812372   -72.20985667 -69.96945784
# ...

# %%
v_rest[:,2].sum()
#this cell adds all of the values in the 3rd column. The colon indicates that we are not working with rows , and the comma indicates we are taking all of the values in the third and not slicing aa specific value
# Out:
# np.float64(-151.75359464)

# %%
v_rest[1,-2]
#in this code cell I indexed the 2nd row using[1] and the 2nd to last column using the [-2] negative indexing
# Out:
# np.float64(-65.59535842)

# %%
plt.hist(v_rest[0])
#This code makes a histogram of the first row of our variable, as when we index we stafrt at zero and our first value is our row number
# Out:
# (array([  7.,  28., 117., 149.,  96.,  66.,  26.,   6.,   4.,   1.]),
#  array([-85.27155304, -81.26054661, -77.24954018, -73.23853375,
#         -69.22752732, -65.2165209 , -61.20551447, -57.19450804,
#         -53.18350161, -49.17249518, -45.16148875]),
#  <BarContainer object of 10 artists>)

# %%
v_rest_mean_sst=st.mean(v_rest[0])
v_rest_mean_pvalb=st.mean(v_rest[1])
print(v_rest_mean_sst)
print(v_rest_mean_pvalb)
#This cell creates two variables based on the means of our first two rows
# Out:
# -69.97869017908
# -67.73465864056

# %% [markdown]
# These two means are relatively close, however pvalb neurons seen to have a lower resting potential on average

# %%
import scipy.stats as stats
#this cell imports a module in order to do more complex stats

# %%
stats.ttest_ind(v_rest[0],v_rest[1])
#this cell uses the example code from the pdf, however it replaces the "row1,row2" part with the specific rows in our 'v_rest' variable. Placing the mean variables in did not work
# Out:
# TtestResult(statistic=np.float64(-5.837507010328816), pvalue=np.float64(7.159828660199036e-09), df=np.float64(998.0))

# %% [markdown]
# the result is that our pvalue is 7.25e-9. This is an incredibly low p-value, almost suspeciously low. However, in general I think this makes sense, as our 500 data points in each row gives us an extremely large sample size, so even if the diffences in mean don't look extremely large, the large sample size makes up for that
